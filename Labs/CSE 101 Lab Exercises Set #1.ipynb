# %% [markdown]
# #CSE 101: Computer Science Principles
# ####Stony Brook University, Summer 2020
#
# ### Lab Exercises Set #1
#
# #### Learning Outcomes
# By the end of these exercises you should be able to:
# * Write simple mathematical formulas and expressions in Python.

# %% [markdown]
# #### Credits
#
# Some of the content of this Notebook was taken from http://ix.cs.uoregon.edu/~conery/eic/python/index.html, the website of John Conery's textbook *Explorations in Computing: An Introduction to Computer Science and Python Programming*.
#
# #### A Note About Key Combinations
#
# A caret symbol ⌃ in front of a letter is a shorthand notation that means "use the control key".  For example, `⌃C` means "hold down the control key while typing C".
#
# The ⏎ symbol refers to the Return key.
#
# When you want Python to execute statements in a code cell, type the statements and then hit ⌃⏎, *i.e.* hold down the control key when hitting the return key.

# %% [markdown]
# #### Exercises on Python Arithmetic

# %% [markdown]
# Enter `13 + 2` in the code cell below and hit ⌃⏎. Python should print the result of the expression immediately below the code cell.

# %%
13 + 2
# Out:
# 15

# %% [markdown]
# Try some simple expressions involving other operators. In each case, type ⌃⏎ after you enter the expression.

# %%
2 - 3
# Out:
# -1

# %%
7 / 10
# Out:
# 0.7

# %%
6 / 3
# Out:
# 2.0

# %%
9*2
# Out:
# 18

# %% [markdown]
# Try some expressions with and without parentheses:

# %%
7*(3+2)
# Out:
# 35

# %%
(8-10)/-2
# Out:
# 1.0

# %%
-10/(5-10)
# Out:
# 2.0

# %%
(10-20)/(25/5) - 4*3
# Out:
# -14.0

# %% [markdown]
# Does Python care if you include spaces in the middle of your expressions?  Tell Python to evaluate `3+4`, with no spaces:

# %%
3+4
# Out:
# 7

# %% [markdown]
# Type the expression again, this time with spaces before and after the plus sign:

# %%
3 + 4
# Out:
# 7

# %% [markdown]
# What happens if you leave out an operand? What does Python do if you type `3 + * 5` instead of `3 + 4 * 5`?

# %%
3 + * 5
# Out:
#   File "<ipython-input-12-2a2e32d02229>", line 1
#     3 + * 5
#         ^
# SyntaxError: invalid syntax

# %% [markdown]
# Type an expression that mistakenly uses a letter instead of a number:

# %%
a + 2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-ead3c2111b4d> in <module>()
# ----> 1 a + 2
#
# NameError: name 'a' is not defined

# %% [markdown]
# Type a few expressions to see how Python applies the "PEMDAS" precedence rules (parentheses, exponentiation, multiplication/division, addition/subtraction):

# %%
(4+2)/(7-1)*2+6**2
# Out:
# 38.0

# %% [markdown]
# What do you think Python will do if you enter `8 / 2 + 5 * 3`?  Type the expression in the code cell below.  Did you get the result you expected?

# %%
8/2+5*3
# Out:
# 19.0

# %% [markdown]
# Use Python to evaluate a simple expression such as `3 * 5` where both operands are integers:

# %%
3*5
# Out:
# 15

# %% [markdown]
# Repeat the previous expression, but use floating point numbers:

# %%
3.0*5.0
# Out:
# 15.0

# %% [markdown]
# Do you think Python will allow you to mix integers and floating point numbers? What will happen if you try to multiply 3 by 5.0, or add 1.0 to 6? Try these examples and a few other expressions that mix integers and floating point numbers. Does there seem to be a general rule for determining what kind of output is printed?

# %%
3*5.0
# Out:
# 15.0

# %%
1.0+6
# Out:
# 7.0

# %%
1.01000+2.000
# Out:
# 3.01

# %% [markdown]
# Use Python to evaluate the expression that converts 100° to Celsius:

# %%
fahrenheit = 100
celsius = (fahrenheit - 32)*5/9
celsius
# Out:
# 37.77777777777778

# %% [markdown]
# Repeat the previous exercise, using Python to convert these temperature values to Celsius:
# * 90°
# * 70°
# * 212°
# * 32°

# %%
fahrenheit = 90
celsius = (fahrenheit - 32)*5/9
celsius
# Out:
# 32.22222222222222

# %%
fahrenheit = 70
celsius = (fahrenheit - 32)*5/9
celsius
# Out:
# 21.11111111111111

# %%
fahrenheit = 212
celsius = (fahrenheit - 32)*5/9
celsius
# Out:
# 100.0

# %%
fahrenheit = 32
celsius = (fahrenheit - 32)*5/9
celsius
# Out:
# 0.0

# %% [markdown]
# The formula for converting from Celsius to Fahrenheit is $T_F = T_C \times \frac{9}{5} + 32$.  Use this formula to convert the following temperatures to Fahrenheit:
# * 0°
# * 10°
# * 20°
# * 30°
# * 100°

# %%
celsius = 0
fahrenheit = celsius*9/5+32
fahrenheit
# Out:
# 32.0

# %%
celsius = 10
fahrenheit = celsius*9/5+32
fahrenheit
# Out:
# 50.0

# %%
celsius = 20
fahrenheit = celsius*9/5+32
fahrenheit
# Out:
# 68.0

# %%
celsius = 30
fahrenheit = celsius*9/5+32
fahrenheit
# Out:
# 86.0

# %%
celsius = 100
fahrenheit = celsius*9/5+32
fahrenheit
# Out:
# 212.0

# %% [markdown]
# Type the command that imports the `sqrt` function from the `math` module:

# %%
import math

# %% [markdown]
# Use `sqrt` to compute the square root of 25:

# %%
value = math.sqrt(25)
value
# Out:
# 5.0

# %% [markdown]
# The `math` module also defines some important constants.  Type the command that imports the definition of `pi` so you can use it in the current session:

# %%
import math

# %% [markdown]
# Verify `pi` has been imported:

# %%
math.pi
# Out:
# 3.141592653589793

# %% [markdown]
# #### Exercises on Python Variables

# %% [markdown]
# Type the two mathematical expressions and assign them to variables named `x` and `y`:

# %%
x = math.sqrt(25)
y = 1+2
x, y
# Out:
# (5.0, 3)

# %% [markdown]
# (**) Try out a few expressions using these variables:

# %%
x+y
# Out:
# 3

# %%
x**2
# Out:
# 0

# %%
x*y
# Out:
# 0

# %% [markdown]
# Change the value of `x`:

# %%
x=0

# %% [markdown]
# Execute the code marked with a (**) above.  Did the values of these expressions change after you changed the value of `x`?

# %% [markdown]
# Create and assign values to the variables `length`, for representing the long edge of a sheet of paper, and `width`, for representing the short edge.

# %%
length_cm = 30
width_cm = 21

# %% [markdown]
# Write an expression that uses `length` and `width` to compute the area of the sheet of paper and assign it to a variable named `area`. Display the value of `area`.

# %%
area_cm2 = length_cm*width_cm
area_cm2
# Out:
# 630

# %% [markdown]
# ### Exercises on Python Functions

# %% [markdown]
# The formula for converting a Fahrenheit temperature to Celsius is $T_C = (T_F - 32) \times \frac{5}{9}$. Complete the definition of the function `convert(temp_f)` that computes and returns the Celsius equivalent of the Fahrenheit temperature given as `temp_f`.

# %%
def convert(temp_f):
    return (temp_f-32)*5/9

# %% [markdown]
# Call your function and display the returned values for the following Fahrenheit temperatures:
# * 32°
# * 212°
# * -40°

# %%
temp_f = 32
temp_c = convert(temp_f)
temp_c
# Out:
# 0.0

# %%
temp_f = 212
temp_c = convert(temp_f)
temp_c
# Out:
# 100.0

# %%
temp_f = -40
temp_c = convert(temp_f)
temp_c
# Out:
# -40.0

# %% [markdown]
# The formula for simple interest is $Prt$, where:
# * $P$ is the principal
# * $r$ is the annual interest rate, as a decimal
# * $t$ is the time period involved
#
# Complete the definition of the function `def new_balance(principal, rate, years)` that computes the total amount of money in a bank account after `years` years, assuming we started with $`principal` and the interest rate (as a decimal) is `rate`. Note that we don't simply want the interest earned, but rather the interest earned *plus* the starting principal. For example, the the arguments `1000, .05, 3` your function should return `1150.0`.

# %%
def new_balance(principal, rate, years):
    return principal*(1+rate*years)

# %% [markdown]
# Call your function with the arguments `1000, .05, 3` and display the result to verify its correctness.

# %%
principal = 1000
rate = 0.05
years = 3
balance = new_balance(principal, rate, years)
print(f'New Balance: ${balance:.2f}')
# Out:
# New Balance: $1150.00

# %% [markdown]
# ### How to Submit Your Work
#
# 1. Go to the [course website](https://sites.google.com/stonybrook.edu/cse-101/schedule?authuser=0).
#
# 1. Click the **Submit** link for this assignment.
#
# 1. Type your Net ID (not your SBU ID#) on the line provided.
#
# 1. Press the button marked **Add file**.
#
# 1. Click the **My Drive** tab.
#
# 1. Click on the file you wish to submit.
#
# 1. Hit **Select**.
#
# 1. Hit **Submit** to submit your file grading.
