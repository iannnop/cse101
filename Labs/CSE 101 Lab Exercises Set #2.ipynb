# %% [markdown]
# #CSE 101: Computer Science Principles
# ####Stony Brook University, Summer 2020
#
# ### Lab Exercises Set #2
#
# ### Homework Assignment #2
#
# #### Learning Outcomes
# By the end of these exercises you should be able to:
# * Write short code fragments that use if-statements:
#     * with only an if-clause
#     * with an if-clause and an else-clause
#     * with an if-clause and one or more elif-clauses
# * Use string operators and methods to perform basic operations with strings.
# * Use loops to perform basic iterative operations on strings using for-loops.

# %% [markdown]
# #### Credits
#
# Some of the content of this Notebook was taken from http://ix.cs.uoregon.edu/~conery/eic/python/index.html, the website of John Conery's textbook *Explorations in Computing: An Introduction to Computer Science and Python Programming*.
#
# #### A Note About Key Combinations
#
# A caret symbol ⌃ in front of a letter is a shorthand notation that means "use the control key".  For example, `⌃C` means "hold down the control key while typing C".
#
# The ⏎ symbol refers to the Return key.
#
# When you want Python to execute statements in a code cell, type the statements and then hit ⌃⏎, *i.e.* hold down the control key when hitting the return key.

# %% [markdown]
# ### if-statements

# %% [markdown]
# Create a variable `total` and store a positive integer in it. Write a Boolean epression that evaluates to `True` only when `total` is divisible by 4. You do not need to write an if-statement.

# %%
total = 5
total % 4 == 0
# Out:
# False

# %% [markdown]
# Create a variable `length` and store a positive integer in it. Write an if-statement that displays the string `'long'` if `length` is greater than 100 and `'short'`, otherwise.

# %%
length = 100

if length > 100: 
    print('long')

else:
    print('short')
# Out:
# short

# %% [markdown]
# Create a variable `age` and store a positive integer in it. Write an if-statement that displays the string `'adult'` if `age` is in the range 18-64 (inclusive), and `'other`', otherwise. (Hint: use the `a <= x <= b` notation.)

# %%
age = 65

if 18<=age<=64:
    print('Adult')
    
else:
    print('Other')
# Out:
# Other

# %% [markdown]
# The marginal state income tax rates in [Kansas](https://www.incometaxpro.net/tax-rates/kansas.htm) for single people are:
#
# | | Range| |Tax Rate|
# |---------|-----|---------|-------|
# | \$0      | to  | \$15,000 | 3.1%  |
# | \$15,001 | to  | $30,000 | 5.25% |
# | \$30,001 | and | up      | 5.7%  |
#
# For example, someone who earns \$35,000 will pay 3.1% tax on the first $15,000 of her salary, 5.25% on the next \$15,000, and 5.7% on the remaining income. Complete the function `compute_tax` that uses a multiway if-statement to compute and return the total tax due for the salary stored in the argument named `salary`. Test your code for each of the following salaries:
# * \$35,000 (tax due should be \$1,537)
# * \$25,000 (tax due should be \$517.50)
# * \$5,000 (tax due should be \$155)

# %%
def compute_tax(salary):
    if 0 <= salary <= 15000:
        tax = salary*0.031
    elif salary <= 30000:
        tax = 15000*0.031 + (salary - 15000)*0.0525
    else:
        tax = 15000*0.031 + 15000*0.0525 + (salary - 30000)*0.057
    return tax

# %%
tax = compute_tax(35000)
tax
# Out:
# 1537.5

# %%
tax = compute_tax(25000)
tax
# Out:
# 990.0

# %%
tax = compute_tax(5000)
tax
# Out:
# 155.0

# %% [markdown]
# What happens if you provide a negative value for `salary`? Make a copy of your `compute_tax` function below and modify it so that the function to return `-1.0` if `salary` is negative.

# %%
def compute_tax(salary):
    if salary < 0:
        tax = -1.0
    elif 0 <= salary <= 15000:
        tax = salary*0.031
    elif salary <= 30000:
        tax = 15000*0.031 + (salary - 15000)*0.0525
    else:
        tax = 15000*0.031 + 15000*0.0525 + (salary - 30000)*0.057
    return tax

# %% [markdown]
# Now call your revised function with the same test cases as before (`35000`, `25000`, `5000`), as well as a negative number for `salary`.

# %%
tax = compute_tax(35000)
tax
# Out:
# 1537.5

# %%
tax = compute_tax(25000)
tax
# Out:
# 990.0

# %%
tax = compute_tax(5000)
tax
# Out:
# 155.0

# %%
tax = compute_tax(-15000)
tax
# Out:
# -1.0

# %% [markdown]
# Using nested if-statements, write a function that returns the move ticket price for a customer. The pricing guide is as follows, with variables storing the values of interest highlighted in the rules:
# * if `today` is Monday and the customer's `age` is more than 64, the price is \$10
# * if `today` is Monday and the customer's `age` is not more than 64, the price is \$15
# * if `today` is not Monday and the customer's `age` is more than 64, the price is \$12
# * if `today` is not Monday and the customer's `age` is not more than 64, the price is \$17
#
# You may not use the `and` operator for this exercise; you must use if-statements.

# %%
def movie_ticket(today, age):
    if today == 'Monday':
        if age > 64:
            price = 10
        else:
            price = 15
    
    else:
        if age > 64:
            price = 12
        else:
            price = 17

    return price

# %% [markdown]
# Test your code by calling `movie_ticket` four times with arguments so that each return value is different. Display the return value in each case.

# %%
price = movie_ticket('Wednesday', 15)  # example
price
# Out:
# 17

# %%
price = movie_ticket('Sunday', 70)
price
# Out:
# 12

# %%
price = movie_ticket('Monday', 10)
price
# Out:
# 15

# %%
price = movie_ticket('Monday', 80)
price
# Out:
# 10

# %% [markdown]
# ### String Concatenation and Repetition

# %% [markdown]
# Define two strings, one that stores your first name, and another to store your last name.

# %%
first_name = 'Ian'
last_name = 'Wu'

# %% [markdown]
# Write code that will concatenate your names with a space in between and then display the result.

# %%
first_name + ' ' + last_name
# Out:
# 'Ian Wu'

# %% [markdown]
# Use the `*` operator to concatenate 10 copies of your first name together and display the result.

# %%
first_name*10
# Out:
# 'IanIanIanIanIanIanIanIanIanIan'

# %% [markdown]
# ### String Indexing

# %% [markdown]
# Use the `len` function to compute and display the number of letters in your first name.

# %%
len(first_name)
# Out:
# 3

# %% [markdown]
# Use a positive index to extract and display the leftmost character of your first name.

# %%
first_name[0]
# Out:
# 'I'

# %% [markdown]
# Use a positive index to extract and display the rightmost character of your first name.

# %%
first_name[2]
# Out:
# 'n'

# %% [markdown]
# Use a negative index to extract and display the leftmost character of your first name.

# %%
first_name[-3]
# Out:
# 'I'

# %% [markdown]
# Use a negative index to extract and display the rightmost character of your first name.

# %%
first_name[-1]
# Out:
# 'n'

# %% [markdown]
# Use the `len` function to extract and display the rightmost character of your first name.

# %%
first_name[len(first_name)-1]
# Out:
# 'n'

# %% [markdown]
# Write code that attempts to change the letter at index `1` of your first name to `Z`.

# %%
first_name[1] = 'Z'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-28-97ab9ac4c075> in <module>()
# ----> 1 first_name[1] = 'Z'
#
# TypeError: 'str' object does not support item assignment

# %% [markdown]
# Define a new string that stores the words `Computer Science`.

# %%
string = 'Computer Science'

# %% [markdown]
# Use slicing to extract and display the 3 leftmost characters of the string.

# %%
string[:3]
# Out:
# 'Com'

# %% [markdown]
# Use slicing to extract and display the 5 rightmost characters of the string.

# %%
string[-5:]
# Out:
# 'ience'

# %% [markdown]
# Use slicing to extract and display every 3rd character of the string, starting at index 2.

# %%
string[2::3]
# Out:
# 'mt ic'

# %% [markdown]
# Use slicing display the string backwards.

# %%
string[::-1]
# Out:
# 'ecneicS retupmoC'

# %% [markdown]
# ### String Methods

# %% [markdown]
# Define a new string that stores the name `Donald Knuth`.

# %%
name = 'Donald Knuth'

# %% [markdown]
# Use `upper` to display the name in all uppercase.

# %%
name.upper()
# Out:
# 'DONALD KNUTH'

# %% [markdown]
# Use `lower` to display the name in all uppercase.

# %%
name.lower()
# Out:
# 'donald knuth'

# %% [markdown]
# Visit the official [documentation for Python string methods](https://docs.python.org/3/library/stdtypes.html#string-methods) and find a method that will capitalize every word in a string. (Hint: it's not `capitalize`!) Use it to display the string below in "title case". Do not simply modify the contents of the string below.

# %%
country = 'united states of america'
country.title()
# Out:
# 'United States Of America'

# %% [markdown]
# Write an expression to test whether the word `'the'` is present in the string named `country`.

# %%
'the' in country
# Out:
# False

# %% [markdown]
# Use the `replace` method to replace all occurrences of the lowercase letter `e` in `country`, *but do not change the original string stored in* `country`.

# %%
country.replace('e','E')
# Out:
# 'unitEd statEs of amErica'

# %% [markdown]
# Use the `count` method to count and display the number of lowercase letter `e` characters in `country`.

# %%
country.count('e')
# Out:
# 3

# %% [markdown]
# Use only the `strip` method and no slicing or other operators or methods to remove the digit characters from the ends of the string below.

# %%
message = '123454321YOU DID IT!678909876'
message.strip("1234567890")
# Out:
# 'YOU DID IT!'

# %% [markdown]
# ### Comparing Strings

# %% [markdown]
# Use the `<` operator to compare two strings where the first string is lexicographically less than the second string, but alphabetically greater than the second string.

# %%
string1 = 'Banana'
string2 = 'apple'
string1 < string2, string1 > string2
# Out:
# (True, False)

# %% [markdown]
# Create two variables that store two different strings that vary only in capitalization somehow and then compare them with `>`. Does the result make sense?

# %%
variable1 = 'STRING'
variable2 = 'string'
variable1 > variable2
# Out:
# False

# %% [markdown]
# Now use the *inequality* operator to verify that the two strings are unequal, i.e., use the `!=` operator.

# %%
variable1 != variable2
# Out:
# True

# %% [markdown]
# ### Other String Methods
#
# There are methods for testing whether a string begins with or ends with a particular substring. Search the [documentation for string methods](https://docs.python.org/3/library/stdtypes.html#string-methods) and find them.

# %% [markdown]
# Create a variable name `book` and store the string `'The Lord of the Rings'` in that variable.

# %%
book = 'The Lord of the Rings'

# %% [markdown]
# Write a single line of code that checks whether `book` begins with the string `'The'`.

# %%
book[:3] == 'The'
# Out:
# True

# %% [markdown]
# Write a single line of code that checks whether `book` ends with the string `'Onion Rings'`.

# %%
book[-11:] == 'Onion Rings'
# Out:
# False

# %% [markdown]
# ### The `ord` and `chr` Functions

# %% [markdown]
# Display the Unicode value for the capital letter `'P'`.

# %%
ord('P')
# Out:
# 80

# %% [markdown]
# Display the character that has the Unicode value `9992`.

# %%
chr(9992)
# Out:
# '✈'

# %% [markdown]
# Use the `ord` and `chr` functions to display the character that has the code that is 5 greater than the code for the character `'&'`. Hint: it's a mathematical operator.

# %%
chr(ord('&')+5)
# Out:
# '+'

# %% [markdown]
# ### String Processing with Iteration

# %% [markdown]
# Write a loop that computes and displays the sum of the Unicode values of the characters in a string variable named `name`. Provide your own string to store in `name`.

# %%
name = 'This is the string'
unicode_value = 0

for c in name:
    unicode_value += ord(c)

unicode_value
# Out:
# 1708

# %% [markdown]
# Create a string called `movie` and store the title of a movie in it. Pick a movie whose title contains at least 15 characters. Using a for-loop and an if-statement, count and display the number of lowercase vowels in the movie title. (Hint: suppose `ch` stores a particular character from a string. The Boolean condition `ch in 'aeiou'` evaluates to `True` when `ch` stores a vowel.)

# %%
movie = 'John Wick: Chapter 4'
vowel = 'aeiou'

lowercase_vowels = uppercase_vowels = 0

for i in range(len(movie)):
    if movie[i] in vowel:
        lowercase_vowels += 1

    elif movie[i] in vowel.upper():
        uppercase_vowels += 1

print(f'Uppercase Vowels: {uppercase_vowels}\nLowercase Vowels: {lowercase_vowels}')
# Out:
# Uppercase Vowels: 0
# Lowercase Vowels: 4

# %% [markdown]
# ### How to Submit Your Work
#
# 1. Go to the [course website](https://sites.google.com/stonybrook.edu/cse-101/schedule?authuser=0).
#
# 1. Click the **Submit** link for this assignment.
#
# 1. Type your SBU ID# on the line provided.
#
# 1. Press the button marked **Add file**.
#
# 1. Click the **My Drive** tab.
#
# 1. Click on the file you wish to submit.
#
# 1. Hit **Select**.
#
# 1. Hit **Submit** to submit your file grading.
